# %%
import json
import pandas as pd

# %%
with open("dataset.json") as user_file:
  file_contents = user_file.read()

parsed_json = json.loads(file_contents)

# %%
df = pd.DataFrame(parsed_json['data'])
df.tail(15)
# Out:
#             id                                      job_title
# 2485  78995604                           System administrator  \
# 2486  78887799                              Android Developer
# 2487  79904355                        Системный администратор
# 2488  79925634                 Стажер по фронт-энд разработке
# 2489  79850132                            Front-end developer
# 2490  78748399                           Frontend-разработчик
# 2491  79902066  Графический дизайнер (Универсальный Дизайнер)
# 2492  79572169                           Стажёр в IT компанию
# 2493  79839860                 Системный администратор DevOps
# 2494  79883303                            Flutter Программист
# 2495  79850646                     Middle Front-End Developer
# 2496  78857020                                Project Manager
# 2497  79895660                           Графический дизайнер
# 2498  79808489                           Графический дизайнер
# 2499  79925887                         Middle Web разработчик
#
#                                            company_name
# 2485            ООО Pharmaceutical Technical University  \
# 2486                                     ООО BRIO GROUP
# 2487                                ИП ООО Finserv Tech
# 2488                                      ЧП Molly shop
# 2489                                     ООО TEXNO-SOFT
# 2490                                            Rochwin
# 2491                                       ООО Medmedia
# 2492                              ООО Kibera Technology
# 2493  Гос. корп. ЦЕНТР ЦИФРОВОЙ ТРАНСФОРМАЦИИ ПРИ МИ...
# 2494                           ООО TWENTY THREE CHANNEL
# 2495                 O‘ZBEKISTON AKKREDITATSIYA MARKAZI
# 2496  Гос. корп. ЦЕНТР ЦИФРОВОЙ ТРАНСФОРМАЦИИ ПРИ МИ...
# 2497                                   ООО Zamaan Group
# 2498                                       ООО Aslgosht
# 2499                                          InFinBank
#
#                                                location required_experience
# 2485               Ташкент, улица Чингиза Айтматова, 1А            1–3 года  \
# 2486                      Ташкент, Кичик Халка Йули, 44             3–6 лет
# 2487                  Ташкент, улица Шота Руставели, 12         более 6 лет
# 2488                          Ташкент, улица Урикзор, 7        не требуется
# 2489                                               None            1–3 года
# 2490                                               None             3–6 лет
# 2491                                               None            1–3 года
# 2492  Ташкент, Мирзо-Улугбекский район, улица Зиёлил...        не требуется
# 2493                                               None             3–6 лет
# 2494                   Ташкент, 1-й проезд Миробод, 13А            1–3 года
# 2495                 Ташкент, проспект Мустакиллик, 105             3–6 лет
# 2496                                               None            1–3 года
# 2497   Ташкент, Яшнободский район, массив Ташсельмаш, 8            1–3 года
# 2498                     Ташкент, проспект Бунёдкор, 58            1–3 года
# 2499  Ташкент, Мирабадский район, улица Тараса Шевче...            1–3 года
#
#                      job_market
# 2485  Информационные технологии  \
# 2486  Информационные технологии
# 2487  Информационные технологии
# 2488  Информационные технологии
# 2489  Информационные технологии
# 2490  Информационные технологии
# 2491  Информационные технологии
# 2492  Информационные технологии
# 2493  Информационные технологии
# 2494  Информационные технологии
# 2495  Информационные технологии
# 2496  Информационные технологии
# 2497  Информационные технологии
# 2498  Информационные технологии
# 2499  Информационные технологии
#
#                                             description
# 2485  About Pharmaceutical Technical University Phar...  \
# 2486  Описание:  Разработка всей кодовой базы с нуля...
# 2487  Обязанности:  Оказание своевременной IT поддер...
# 2488  Мы ищем стажера, который будет работать с наше...
# 2489  Обязанности:  Разработка фронт-енд web-приложе...
# 2490  Обязанности:  Выполнение поставленных задач в ...
# 2491  Обязанности:  Создание креатива для социальных...
# 2492  ⚡️Компания Kibera Technology объявляет открыты...
# 2493  Чем предстоит заниматься:- Обслуживание, монит...
# 2494  Обязанности:  доработка программы. интеграция ...
# 2495   Формат работы: офис (обговаривается). Занятос...
# 2496  Задачи:-Взаимодействие с командами разработчик...
# 2497  Обязанности:  Разработка дизайна цифровых и пе...
# 2498  Компания "ASL BARAKA" приглашает на должность ...
# 2499  InfinBANK помогает клиентам рационально и эффе...
#
#                                         required_skills
# 2485  Internet, Ms access, Microsoft access, Access,...
# 2486  Java, Kotlin, Android sdk, Android, Английский...
# 2487
# 2488
# 2489                            Vue.js, Js, Java script
# 2490  Javascript, Css3, Html5, Git, React.js, Rest a...
# 2491  Adobe photoshop, Adobe illustrator, Креативнос...
# 2492
# 2493  Linux, Postgresql, Docker, Администрирование с...
# 2494  Flutter, Dart, Git, Rest, Android sdk, Json, R...
# 2495  Git, Html5, Css3, Ооп, Linux, Java script, Rea...
# 2496  Управление проектами, Деловое общение, Подгото...
# 2497  Coreldraw, Adobe illustrator, Adobe after effe...
# 2498  Дизайн, Работать в команде, Графические редакт...
# 2499
